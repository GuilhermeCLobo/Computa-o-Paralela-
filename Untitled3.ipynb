# %% [markdown]
# <a href="https://colab.research.google.com/github/GuilhermeCLobo/Computa-o-Paralela-/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

imagem = mpimg.imread('/content/kodim23.png')

plt.imshow(imagem)

plt.show()

# %%
import cv2
import matplotlib.pyplot as plt

imagem = cv2.imread('/content/kodim23.png')

imagem_rgb = cv2.cvtColor(imagem, cv2.COLOR_BGR2RGB)

plt.imshow(imagem_rgb)

plt.show()

# %%
from skimage import io
import matplotlib.pyplot as plt

imagem = io.imread('/content/kodim23.png')

plt.imshow(imagem)

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

def grayscale(img_color):
    Media = 0
    for x in range(512):
      for y in range(768):
        for i in range(3):
          Media = Media + img_color[x, y, i]
        img_color[x, y, 0] = Media/3
        img_color[x, y, 1] = Media/3
        img_color[x, y, 2] = Media/3
        Media = 0
    return img_color

img = Image.open('/content/kodim23.png')
img_array = np.array(img)
img_array_grayscale = grayscale(img_array)
print(f'Original: {img_array.shape} {type(img_array)}')
print(f'Cinza: {img_array_grayscale.shape} {type(img_array_grayscale)}')
plt.imshow(img_array_grayscale, cmap=plt.cm.gray)
plt.show()
# Out:
# Original: (512, 768, 3) <class 'numpy.ndarray'>
# Cinza: (512, 768, 3) <class 'numpy.ndarray'>

# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

def grayscale(img_color):
    for x in range(512):
      for y in range(768):
        Y = img_color[x, y, 0] * 0.2125 + img_color[x, y, 1] * 0.7154 + img_color[x, y, 2] * 0.0721
        img_color[x, y, 0] = Y
        img_color[x, y, 1] = Y
        img_color[x, y, 2] = Y
    return img_color

img = Image.open('/content/kodim23.png')
img_array = np.array(img)
img_array_grayscale = grayscale(img_array)
print(f'Original: {img_array.shape} {type(img_array)}')
print(f'Cinza: {img_array_grayscale.shape} {type(img_array_grayscale)}')
plt.imshow(img_array_grayscale, cmap=plt.cm.gray)
plt.show()
# Out:
# Original: (512, 768, 3) <class 'numpy.ndarray'>
# Cinza: (512, 768, 3) <class 'numpy.ndarray'>
